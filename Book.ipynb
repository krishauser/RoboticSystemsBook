# %% [markdown]
# Robotic Systems (draft)
# =================
#
# Kris Hauser
#
# Duke University
#
# Last update: 8/25/2018
#
#
# Table of Contents
# =================
#
# * [Preface](Preface.ipynb)
#
# * Section I. Introduction
#   * [Chapter 1. What is robotics?](WhatIsRobotics.ipynb)
#   * [Chapter 2. Anatomy of a robot](AnatomyOfARobot.ipynb) **incomplete**
#
# * Section II. Modeling
#
#   * [Chapter 3. Coordinate transformations](CoordinateTransformations.ipynb)
#   * [Chapter 4. 3D rotations](3DRotations.ipynb)
#   * [Chapter 5. Robot kinematics](Kinematics.ipynb)
#   * [Chapter 6. Inverse kinematics](InverseKinematics.ipynb) **needs fixing**
#   * [Chapter 7. Representing geometry](Geometry.ipynb) **incomplete**
#
# * Section III. Motion Planning
#
#   * [Chapter 8. What is motion planning?](WhatIsMotionPlanning.ipynb)
#   * [Chapter 9. Motion planning in simple geometric spaces](GeometricMotionPlanning.ipynb) **needs fixing**
#   * [Chapter 10. Sampling based motion planning](SamplingBasedMotionPlanning.ipynb) **needs conversion**
#   * [Chapter 11. Extensions to motion planning](ExtensionsToMotionPlanning.ipynb) **needs conversion**
#
# * Section IV. Dynamics and Control
#
#   * [Chapter 12. What are dynamics and control?](WhatAreDynamicsAndControl.ipynb) **needs conversion**
#   * [Chapter 13. Robot dynamics](RobotDynamics.ipynb) **needs conversion**
#   * [Chapter 14. Stabilizing controlled systems](Control.ipynb) **needs conversion**
#   * [Chapter 15. Control of articulated robots](RobotControl.ipynb) **needs conversion**
#   * [Chapter 16. Optimal control](OptimalControl.ipynb) **needs conversion**
#
# * Section V. Perception **incomplete**
#
# * Section VI. Learning and Calibration **incomplete**
#
# * Appendix A. Mathematical Preliminaries
#
#   * [A.1. Linear algebra](LinearAlgebra.ipynb)
#   * [A.2. Real analysis and calculus of many variables](Calculus.ipynb)
#   * [A.3. Probability distributions](Probability.ipynb) **needs fixing**
#
# * Appendix B. Numerical Methods
#
#   * [B.1. Numerical errors](NumericalErrors.ipynb)
#   * [B.2. Matrix computations](MatrixComputations.ipynb) **incomplete**
#   * [B.3. Optimization](Optimization.ipynb) **incomplete**
#
# * Appendix C. Computational methods **needs conversion**
#
# Notes
# =================
#
# This book is a work in progress!  The source material is my lecture notes, which are progressively being converted to Jupyter Notebook and HTML format.  The tools that I am using may create broken matrix equations, links, references, or incorrectly formatted figures.  I am trying to correct them as I go, but I may miss some.  If you notice anything that needs correcting, please email me at kris.hauser@duke.edu.
